# %% [markdown]
# # Combined Pandas and Visualization Project
#
# This notebook integrates all code cells from `Pandas.ipynb` and `Visualisation.ipynb` into a single project sample.

# %% [markdown]
# ## Section 1: Pandas Data Handling

# %% [markdown]
# # ***Pandas***
#
# # pandas is a Python package ( module) providing fast, flexible, and expressive data structures designing tool to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the
# # fundamental high-level building block for doing practical, real world data analysis in Python.
# # Pandas is a data management tool in a best shape
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Structure
# **Pandas** docs : In 0.20.0, Panel is deprecated and will be removed in a future version. The 3-
# D structure of a Panel is much less common for many types of data analysis, than the 1-D of
# the Series or the 2-D of the DataFrame

# %% [markdown]
# ### **1 - Series**
#
# ## pandas.Series()
#
# # Pandas docs : One-dimensional ndarray with axis labels (including time series).
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this code we imporet Pandas as pd

# %% [markdown]
# ## Series structure is very useful to define time series and define years as index

# %% [markdown]
# ## The function Series in Pandas generates a serie which by defalt: the index number starts from 0.

# %%
# !pip install pandas # first we install pandas in google colabe-notebook
import pandas as pd # in python  we should use the name of the library before each function , and by this code we make a abrriviation of pandas as pd

# %%
my_series = pd.Series([10,23,33,43,53])
my_series
# Out:
# 0    10
# 1    23
# 2    33
# 3    43
# 4    53
# dtype: int64

# %% [markdown]
# ### in Pandas , even you do not assign an index , it assigns automatically numbers which start from 0 as index

# %%
my_series2 = pd.Series([3,5,7,3,2,4,9])
my_series2
# Out:
# 0    3
# 1    5
# 2    7
# 3    3
# 4    2
# 5    4
# 6    9
# dtype: int64

# %% [markdown]
# ## Make a time series with the year index

# %%
my_series3 = pd.Series([10, 20, 30,40,50],index=['1996','1998','1999','2000','2001'])
#print(my_series2) # the only name variable here means print it
my_series3
# Out:
# 1996    10
# 1998    20
# 1999    30
# 2000    40
# 2001    50
# dtype: int64

# %%
my_series3['2001']
# Out:
# np.int64(50)

# %% [markdown]
# ### Show Values

# %%
my_series3.values
# Out:
# array([10, 20, 30, 40, 50])

# %% [markdown]
# ### Show index

# %%
my_series3.index
# Out:
# Index(['1996', '1998', '1999', '2000', '2001'], dtype='object')

# %%
my_series2[1]
# Out:
# np.int64(5)

# %% [markdown]
# ## **Every series in Pandas has two elements**
#
# 1- index
#
# 2-another is value (known as the parameter of each index)

# %%
my_series2.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
my_series = pd.Series([10, 20, 30,40,50],index=['row1','row2','row3','row4','row5'])
my_series
# Out:
# row1    10
# row2    20
# row3    30
# row4    40
# row5    50
# dtype: int64

# %%
my_series.row1
# Out:
# np.int64(10)

# %%
my_series[3]
# Out:
# <ipython-input-21-90cad6a29ac4>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   my_series[3]
# np.int64(40)

# %% [markdown]
# ## *indexing*

# %%
my_series
# Out:
# row1    10
# row2    20
# row3    30
# row4    40
# row5    50
# dtype: int64

# %% [markdown]
# ### Calling the row by using logical signs

# %%
my_series[my_series == 10] # if you want to use the logical operation of equal = we should type two times ==
# Out:
# row1    10
# dtype: int64

# %%
my_series[my_series>=20]
# Out:
# row2    20
# row3    30
# row4    40
# row5    50
# dtype: int64

# %% [markdown]
# # **The most important advantage of pandas is to define index for data and specify the address of the data**

# %% [markdown]
# ### *Example : Set alphabet label as new index*

# %%
my_series.index
# Out:
# Index(['row1', 'row2', 'row3', 'row4', 'row5'], dtype='object')

# %%
my_series.index = ['A','B','C','D','E']
my_series
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
my_series[1]
# Out:
# <ipython-input-19-7ee61916e10f>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   my_series[1]
# np.int64(20)

# %% [markdown]
# # **2 - DataFrame**
#
# `pandas.DataFrame()`
#
# ## Two-dimensional size-mutable, potentially heterogeneous tabular data
# ## structure with labeled axes (rows and columns). Arithmetic operations align on both row and column labels.  It is  primary fundamental pandas data structure
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
# #**5 Methods for creation DataFrame**

# %% [markdown]
# #**The First Method**: Create DataFrame with Array
#
#
# ---
#
#
# ## To make a DataFrame , first we define an Array and then by the code of `pd.DataFrame()` or `np.array`, we assign this array to a DataFrame structure(Table)

# %%
import numpy as np # numpy is a library which is used for mathematic operations and victorization of data
my_array = np.array([[1 ,5 ,9 ,10,5],[2 ,6 , 10,14,6],[3 ,7 ,11 ,15,45],[4 ,8 ,12 ,16,56]]) # here we define an aray 2D

# %%
my_array
# Out:
#    0  1   2   3   4
# 0  1  5   9  10   5
# 1  2  6  10  14   6
# 2  3  7  11  15  45
# 3  4  8  12  16  56

# %%
my_array = pd.DataFrame([[1 ,5 ,9 ,10,5],[2 ,6 , 10,14,6],[3 ,7 ,11 ,15,45],[4 ,8 ,12 ,16,56]])

# %%
my_array
# Out:
#    0  1   2   3   4
# 0  1  5   9  10   5
# 1  2  6  10  14   6
# 2  3  7  11  15  45
# 3  4  8  12  16  56

# %% [markdown]
# **Second Example**

# %%
import pandas as pd

# Create a DataFrame of employees:
df = pd.DataFrame({
    "Name":   ["Alice", "Bob",    "Carol"],
    "Age":    [   30,     25,       27],
    "Salary": [60000,  55000,    62000]
})

df
# Out:
#     Name  Age  Salary
# 0  Alice   30   60000
# 1    Bob   25   55000
# 2  Carol   27   62000

# %%
# Define my_array before using it
my_array = [[ 1,  5,  9, 10,  5],
 [ 2,  6, 10, 14,  6],
 [ 3,  7, 11, 15, 45],
 [ 4,  8, 12, 16, 56]]

# %%
import pandas as pd

my_df = pd.DataFrame(
    my_array,
    index = ['row1', 'row2', 'row3', 'row4'],      # names for each row
    columns = ['Var1', 'Var2', 'Var3', 'Var4', 'Var5']  # names for each column
)
my_df
# Out:
#       Var1  Var2  Var3  Var4  Var5
# row1     1     5     9    10     5
# row2     2     6    10    14     6
# row3     3     7    11    15    45
# row4     4     8    12    16    56

# %%
my_df.loc['row3', 'Var4']
# Out:
# np.int64(15)

# %% [markdown]
# #Correlation Matrix
#
# ##matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables.

# %%
# @title Correlation Matrix

import matplotlib.pyplot as plt
import seaborn as sns #prettier statistical plots like heatmaps.
plt.figure()
sns.heatmap(my_df.corr(), annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # **The 2nd Method**: Create DataFrame with Dictionary
#
#
#
# ---
#
#
#
# ## Dictionary items are presented in key value pairs, and can be referred to by using the key name.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## by DEFULT Pandas put the key as ( the column name)  and value in this  column not as row

# %%
my_dict = {'col1':[1,2,3,4],'col2':[5,6,7,0],'col3':[9,10,11,12],'col4':[13,14,15,19],'col5':[16,17,18,20]}
my_dict
# Out:
# {'col1': [1, 2, 3, 4],
#  'col2': [5, 6, 7, 0],
#  'col3': [9, 10, 11, 12],
#  'col4': [13, 14, 15, 19],
#  'col5': [16, 17, 18, 20]}

# %%
my_df2 = pd.DataFrame(my_dict,index=['row1','row2','row3','row4']) # the name of the columns are automaticaly assigend by the name of the keys in my_dict
my_df2
# Out:
#       col1  col2  col3  col4  col5
# row1     1     5     9    13    16
# row2     2     6    10    14    17
# row3     3     7    11    15    18
# row4     4     0    12    19    20

# %% [markdown]
# # **The 3rd Method** : Importing data files directretly from WEB
#
# ---

# %% [markdown]
# #Point "pd.read_*" at a URL
# Most pandas “read” functions accept any HTTP(S) address where the raw file lives. As long as it’s publicly accessible (no login required), pandas will download and parse it for you:
#
#    this is works:
#
#    1- Panda issues an HTTP GET
#
#    2- Panda streams the bytes into the Memory
#
#    3- Then parses them like a local file
#
# #**which helps you for:**
#
# 1- Always beeing up-to-date
#
# 2- Often only a few hundred rows, easy to cache and version-control

# %%
import pandas as pd

# CSV on the web:
url = "https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv"
df_csv = pd.read_csv(url)

# JSON on the web:
url = "https://jsonplaceholder.typicode.com/users"
df_json = pd.read_json(url)

# Excel on the web (must be .xls/.xlsx):
# The original URL returned a 404 error,
# indicating the file was not found at that location.
# Update to a valid URL containing an .xls or .xlsx file.
url = "https://github.com/chris1610/pbpython/raw/master/data/salesfunnel.xlsx" # This is a valid URL to an .xlsx file
df_xls = pd.read_excel(url)

# %%
data3 = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Housing%20Price%20Index%20Regression/monthly-hpi.csv')
data3
# Out:
#           date  housing_price_index
# 0   2010-11-01               186.07
# 1   2010-12-01               183.27
# 2   2011-01-01               181.35
# 3   2011-02-01               179.66
# 4   2011-03-01               178.84
# ..         ...                  ...
# 68  2016-07-01               241.59
# 69  2016-08-01               242.09
# 70  2016-09-01               242.27
# 71  2016-10-01               241.88
# 72  2016-11-01               242.21
#
# [73 rows x 2 columns]

# %% [markdown]
# ## **Show the DataFrame genral information**
#
#
# ---

# %%
data3.index # in python , when we use '.' , generaly it means this a part of main object, for example here main object is my_df now by '.' we ask its index which ia apart of dataframe
# Out:
# RangeIndex(start=0, stop=73, step=1)

# %%
data3.info()# explain the general information about the DataFrame, number of columns, rows and the type of data such as int,str,float,boolean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 73 non-null     object
#  1   housing_price_index  73 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ### ***Show Columns Name***

# %%
data3.describe() # describe is very important command to get general information about the DataFrame
# Out:
#        housing_price_index
# count            73.000000
# mean            206.338082
# std              20.105455
# min             178.840000
# 25%             188.260000
# 50%             205.340000
# 75%             224.790000
# max             242.270000

# %%
data3.columns # This command shows us the name of columns
# Out:
# Index(['date', 'housing_price_index'], dtype='object')

# %%
data3
# Out:
#           date  housing_price_index
# 0   2010-11-01               186.07
# 1   2010-12-01               183.27
# 2   2011-01-01               181.35
# 3   2011-02-01               179.66
# 4   2011-03-01               178.84
# ..         ...                  ...
# 68  2016-07-01               241.59
# 69  2016-08-01               242.09
# 70  2016-09-01               242.27
# 71  2016-10-01               241.88
# 72  2016-11-01               242.21
#
# [73 rows x 2 columns]

# %%
data3.shape # this commad shows the size of the dataframe including numbers of rows and columns
# Out:
# (73, 2)

# %%
data3.head() # by this code we see the first 5 rows of the dataframe
# Out:
#          date  housing_price_index
# 0  2010-11-01               186.07
# 1  2010-12-01               183.27
# 2  2011-01-01               181.35
# 3  2011-02-01               179.66
# 4  2011-03-01               178.84

# %%
data3.head(8)# if you mention a number like 8  after head then pandas shows the first 8 rows
# Out:
#          date  housing_price_index
# 0  2010-11-01               186.07
# 1  2010-12-01               183.27
# 2  2011-01-01               181.35
# 3  2011-02-01               179.66
# 4  2011-03-01               178.84
# 5  2011-04-01               180.80
# 6  2011-05-01               182.11
# 7  2011-06-01               183.85

# %%
data3.tail()# by this code we see the last 5 rows of the dataframe
# Out:
#           date  housing_price_index
# 68  2016-07-01               241.59
# 69  2016-08-01               242.09
# 70  2016-09-01               242.27
# 71  2016-10-01               241.88
# 72  2016-11-01               242.21

# %% [markdown]
# ### **Selecting**

# %%
my_df
# Out:
#       Var1  Var2  Var3  Var4  Var5
# row1     1     5     9    10     5
# row2     2     6    10    14     6
# row3     3     7    11    15    45
# row4     4     8    12    16    56

# %% [markdown]
# # in LOC function the first [   ] means the row (name), the second [ ] means column ( number or name)
#
# ## Note: if we put number inside of bracket for column it means we address a specefic column

# %%
# Selection of the specific row
my_df.loc['row1'][:]# : means all of the columns for row1
# Out:
# Var1     1
# Var2     5
# Var3     9
# Var4    10
# Var5     5
# Name: row1, dtype: int64

# %% [markdown]
# ## If you want to select a specific cell in a dataframe , you can use the LOC.['Name of row '][number of column] , but there are also other method such as dataframe['name of row','name of column]

# %%
my_df.loc['row1'][2] # 2 is the number of  the column which starts from 0 , it is the third column
# Out:
# <ipython-input-56-5c7600d347be>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   my_df.loc['row1'][2] # 2 is the number of  the column which starts from 0 , it is the third column
# np.int64(9)

# %%
my_df.loc['row1','Var2']
# Out:
# np.int64(5)

# %% [markdown]
# ## change the value by location

# %%
my_df.loc['row1','Var3']= 10000 # we change the value of the cell in this table
my_df # just to show again the dataframe to see the chanege
# Out:
#       Var1  Var2   Var3  Var4  Var5
# row1     1     5  10000    10     5
# row2     2     6     10    14     6
# row3     3     7     11    15    45
# row4     4     8     12    16    56

# %%
my_df.loc['row1','Var3']
# Out:
# np.int64(10000)

# %% [markdown]
# ### `iloc` is using for selecting the raw by the number

# %%
my_df.iloc[0][:] # so if we want to select the raw by the number we have to use the iloc not loc
# Out:
# Var1        1
# Var2        5
# Var3    10000
# Var4       10
# Var5        5
# Name: row1, dtype: int64

# %%
my_df.loc['row1']['Var3']
# Out:
# np.int64(10000)

# %% [markdown]
# ## So: **`loc` is with the Index-name but `iloc`  is with the row-number.**

# %%
my_df.iloc[0][:]
# Out:
# Var1        1
# Var2        5
# Var3    10000
# Var4       10
# Var5        5
# Name: row1, dtype: int64

# %%
my_df.iloc[1,1]
# Out:
# np.int64(6)

# %% [markdown]
# # To show/address of whole values of one column we can use this code : DataFrame ['Name of column']. But do not forget that inside of the [...] should be only name of column not its number.

# %%
my_df['Var1']
# Out:
# row1    1
# row2    2
# row3    3
# row4    4
# Name: Var1, dtype: int64

# %%
my_df['Var2']
# Out:
# row1      5
# row2    100
# row3      7
# row4      8
# Name: Var2, dtype: int64

# %% [markdown]
# # ***Edit a DataFrame***
#
#
# ---

# %% [markdown]
# ## 1- To add new row , we should use the fumction of ***loc*** (not iloc).
#
# ##2- To add column , it is easier and we need only asign new column by one array.
#
# ## 3- This method is also used for change the values of columns

# %%
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1     1     5  10000    10     5    23
# row2     2     6     10    14     6    25
# row3     3     7     11    15    45    29
# row4     4     8     12    16    56    26

# %%
my_df['Var6'] = [23 ,25 ,29,26] # adding new column
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1     1     5  10000    10     5    23
# row2     2     6     10    14     6    25
# row3     3     7     11    15    45    29
# row4     4     8     12    16    56    26

# %%
my_df['Var5'] = [230 ,250 ,290 ,403] # changing the whole values of one column
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1     1     5  10000    10   230    23
# row2     2     6     10    14   250    25
# row3     3     7     11    15   290    29
# row4     4     8     12    16   403    26

# %% [markdown]
# # **How to change the amount of a specific cell in the DataFrame**
#
#
# ---

# %% [markdown]
# # We change exactly the value of one cell ( specefic row , colum)

# %%
my_df.loc['row1','Var1'] = 500
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   500     5  10000    10   230    23
# row2     2     6     10    14   250    25
# row3     3     7     11    15   290    29
# row4     4     8     12    16   403    26

# %%
my_df.loc[['row1','row2'],'Var1'] = 20 # multiple change of two rows with the same column
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1    20     5  10000    10   230    23
# row2    20     6     10    14   250    25
# row3     3     7     11    15   290    29
# row4     4     8     12    16   403    26

# %%
my_df.loc[['row1','row2'],['Var1','Var2']] = 180 #multiple change of two rows with two columns
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   180   180  10000    10   230    23
# row2   180   180     10    14   250    25
# row3     3     7     11    15   290    29
# row4     4     8     12    16   403    26

# %% [markdown]
# # ***Delete in Pandas***
#
#
# ---

# %% [markdown]
# # **In Python , when you see the word of drop , it means python deletes some part of the data**
# ### *The function Drop is for deleting a part of the Dataframe*

# %% [markdown]
# # **in the argument of drop, the meaning of axis=0 means delete row with the mentioned index name and axis = 1 means delete column with the mentioned column name**

# %% [markdown]
# # If we use the function drop , this function does not delete columns and rows permanentely. So we have to define a new dataframe and we assign it to dropped dataFranme like the below example

# %%
my_df
df_dropped = my_df.drop(index='row2',columns='Var5') # index and columns are arguments for function drop
df_dropped
# Out:
#       Var1  Var2   Var3  Var4  Var6
# row1   180   180  10000    10    23
# row3     3     7     11    15    29

# %%
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   180   180  10000    10   230    23
# row2   180   180     10    14   250    25
# row3     3     7     11    15   290    29

# %% [markdown]
# ##1- The argument of inplace if is True means that you keep the change permanentely and if it is False , it is temproral change
# ##2- if you do not mention an argument in the function, Python considers its default value which in the case of in place is False.

# %%
my_df.drop('row2',axis=0,inplace=True) # the argument of inplace if is True means that you keep the change permanentely and if it is False , it is temproral change
# if you do not mention an argument in the function, Python considers its default value which in the case of in place is False.

# %%
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   180   180  10000    10   230    23
# row3     3     7     11    15   290    29

# %% [markdown]
# ### **Remember that the drop() function returns a new DataFrame by default, leaving the original DataFrame unchanged. If you want to modify the original DataFrame in-place, you can use the inplace=True argument:**

# %%
my_df.drop('row3',axis=0,inplace=True)
my_df
# Out:
#       Var1  Var2  Var4  Var5  Var6
# row1   180   180    10   300    23
# row5   500   600   800  1111  1000

# %% [markdown]
# ## **Renaming**
#
#
# ---

# %% [markdown]
# # for permanent renaming we should asign new data frame

# %% [markdown]
# ### DataFrame.rename(columns = { ' ' : })

# %%
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   180   180  10000    10   230    23
# row3     3     7     11    15   290    29

# %%
renamed2 = my_df.rename(columns={'Var4':'col_four'})

# %%
renamed2
# Out:
#       Var1  Var2   Var3  col_four  Var5  Var6
# row1   180   180  10000        10   230    23
# row3     3     7     11        15   290    29

# %%
renamed2 = my_df.rename(index={'row3':'eee'},columns={'Var4':'column_four'})
renamed2
# Out:
#       Var1  Var2   Var3  column_four  Var5  Var6
# row1   180   180  10000           10   230    23
# eee      3     7     11           15   290    29

# %%
my_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   180   180  10000    10   230    23
# row3     3     7     11    15   290    29

# %% [markdown]
# ## ***Replacing***
#
#
# ---

# %%
replaced_df = my_df.replace({7:100,14:200})
replaced_df
# Out:
#       Var1  Var2   Var3  Var4  Var5  Var6
# row1   180   180  10000    10   230    23
# row2   180   180     10   200   250    25
# row3     3   100     11    15   290    29

# %% [markdown]
# # **4th Method of Dataframe creation : Importing the Data**
#
#
# ---
#
#
#
# ### **What shoud we do when we want to work on a specefic file in Google Drive:**
#
# # Frist Upload files in Google drive ( cloud)
# # Second Make connection between your cloud storage ( mydrive) and cloud processors ( google Colab) = MOUNTING
# # Third : Read your specific file by Python Codes

# %%
from google.colab import drive #interacting with Google Drive within Colab notebooks
drive.mount('/content/drive') #making the connection between the cloud storage and cloud processors
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df200=pd.read_csv('/content/bank-loan.csv')

# %%
df200
# Out:
#      age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0     41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1     27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2     40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3     41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4     24   2       2        0      28     17.3   1.787436  3.056564      1.0
# ..   ...  ..     ...      ...     ...      ...        ...       ...      ...
# 845   34   1      12       15      32      2.7   0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7   4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8   0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8   0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9   0.899130  4.389870      NaN
#
# [850 rows x 9 columns]

# %%
from matplotlib import pyplot as plt # improting the Matplotlib's plotting interface under the name of plt (calling by the functions)
df200['age'].plot(kind='hist', bins=20, title='age') # selecting age column, making the histogram, split the age in 20 equal sized intervals
plt.gca().spines[['top', 'right',]].set_visible(False) # calling "Get Current Axes" for drewing the plot, making the results in clear visibility

# %%
from matplotlib import pyplot as plt
df200['employ'].plot(kind='line', figsize=(20, 4), title='employ') # drawing the line plot, making figure 8 inches wide and 4 inches tall, titled as "employ"
plt.gca().spines[['top', 'right']].set_visible(False) # calling "Get Current Axes" for drewing the plot, structuring of the plot in 4 bordres, making the clear visibility.

# %%
df200.info() # non-null meanis that how many entries in the special column that are not missing.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       850 non-null    int64
#  1   ed        850 non-null    int64
#  2   employ    850 non-null    int64
#  3   address   850 non-null    int64
#  4   income    850 non-null    int64
#  5   debtinc   850 non-null    float64
#  6   creddebt  850 non-null    float64
#  7   othdebt   850 non-null    float64
#  8   default   700 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 59.9 KB

# %%
df200.head()
# Out:
#    age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0   41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4   24   2       2        0      28     17.3   1.787436  3.056564      1.0

# %%
df200.head(8)
# Out:
#    age  ed  employ  address  income  debtinc   creddebt    othdebt  default
# 0   41   3      17       12     176      9.3  11.359392   5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202   4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075   2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720   0.821280      0.0
# 4   24   2       2        0      28     17.3   1.787436   3.056564      1.0
# 5   41   2       5        5      25     10.2   0.392700   2.157300      0.0
# 6   39   1      20        9      67     30.6   3.833874  16.668126      0.0
# 7   43   1      12       11      38      3.6   0.128592   1.239408      0.0

# %%
df200.tail()
# Out:
#      age  ed  employ  address  income  debtinc  creddebt   othdebt  default
# 845   34   1      12       15      32      2.7  0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7  4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8  0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8  0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9  0.899130  4.389870      NaN

# %%
df200.describe()
# Out:
#               age          ed      employ     address      income     debtinc  \
# count  850.000000  850.000000  850.000000  850.000000  850.000000  850.000000
# mean    35.029412    1.710588    8.565882    8.371765   46.675294   10.171647
# std      8.041432    0.927784    6.777884    6.895016   38.543054    6.719441
# min     20.000000    1.000000    0.000000    0.000000   13.000000    0.100000
# 25%     29.000000    1.000000    3.000000    3.000000   24.000000    5.100000
# 50%     34.000000    1.000000    7.000000    7.000000   35.000000    8.700000
# 75%     41.000000    2.000000   13.000000   12.000000   55.750000   13.800000
# max     56.000000    5.000000   33.000000   34.000000  446.000000   41.300000
#
#          creddebt     othdebt     default
# count  850.000000  850.000000  700.000000
# mean     1.576805    3.078789    0.261429
# std      2.125840    3.398803    0.439727
# min      0.011696    0.045584    0.000000
# 25%      0.382176    1.045942    0.000000
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df200)
# Out:
# https://docs.google.com/spreadsheets/d/1iCZW2wCShFVZ5ALOy1yU5WgCAxD5jdOZXx3c4Gt0Xvs/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1iCZW2wCShFVZ5ALOy1yU5WgCAxD5jdOZXx3c4Gt0Xvs/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# example 2
#
# ---

# %%
data = pd.read_csv('/content/smartphones.csv')
data
# Out:
#         Name        OS  Capacity  Ram  Weight    Company  inch
# 0  Galaxy S8   Android        64    4   149.0    Samsung   5.8
# 1  Lumia 950  windows         32    3   150.0  Microsoft   5.2
# 2  Xpreia L1   Android        16    2   180.0       Sony   5.5
# 3  iphone 7        ios       128    2   138.0      Apple   4.7
# 4    U Ultra   Android        64    4   170.0        HTC   5.7
# 5  Galaxy S5   Android        16    2   145.0    Samsung   5.1
# 6  iphone 5s       ios        32    1   112.0      Apple   4.0
# 7    Moto G5   Android        16    3   144.5   Motorola   5.0
# 8     Pixel    Android       128    4   143.0     Google   5.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      9 non-null      object
#  1   OS        9 non-null      object
#  2   Capacity  9 non-null      int64
#  3   Ram       9 non-null      int64
#  4   Weight    9 non-null      float64
#  5   Company   9 non-null      object
#  6   inch      9 non-null      float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 636.0+ bytes

# %% [markdown]
# ###**When you call "data.describe()" on a DataFrame, pandas computes a set of summary statistics for each numeric column. Here’s what each row tells you, using your output**
#
# Statistic | What it means
#
#
# count | Number of non-missing values in that column
#
#
# mean | The average (sum of values divided by count)
#
#
# std | “Standard deviation”—how spread-out values are around the mean
#
#
# min | The smallest value in the column
#
#
# 25% | The first quartile (25th percentile): one-quarter of the data lie at or below this value
#
#
# 50% | The median (50th percentile): half of the data lie at or below this value
#
#
# 75% | The third quartile (75th percentile): three-quarters of data lie at or below this value (Median)
#
#
# max | The largest value in the column

# %%
data.describe()
# Out:
#          Capacity       Ram      Weight      inch
# count    9.000000  9.000000    9.000000  9.000000
# mean    55.111111  2.777778  147.944444  5.111111
# std     45.333333  1.092906   19.219854  0.548736
# min     16.000000  1.000000  112.000000  4.000000
# 25%     16.000000  2.000000  143.000000  5.000000
# 50%     32.000000  3.000000  145.000000  5.100000
# 75%     64.000000  4.000000  150.000000  5.500000
# max    128.000000  4.000000  180.000000  5.800000

# %%
import pandas as pd
data3=pd.read_csv('/content/Home Price.csv')

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 36 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   LotFrontage    1232 non-null   float64
#  2   LotArea        1459 non-null   int64
#  3   OverallQual    1459 non-null   int64
#  4   OverallCond    1459 non-null   int64
#  5   YearBuilt      1459 non-null   int64
#  6   YearRemodAdd   1459 non-null   int64
#  7   MasVnrArea     1444 non-null   float64
#  8   BsmtFinSF1     1458 non-null   float64
#  9   BsmtFinSF2     1458 non-null   float64
#  10  BsmtUnfSF      1458 non-null   float64
#  11  TotalBsmtSF    1458 non-null   float64
#  12  1stFlrSF       1459 non-null   int64
#  13  2ndFlrSF       1459 non-null   int64
#  14  LowQualFinSF   1459 non-null   int64
#  15  GrLivArea      1459 non-null   int64
#  16  BsmtFullBath   1457 non-null   float64
# ...

# %%
data3.head(9)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          20         80.0    11622            5            6       1961
# 1          20         81.0    14267            6            6       1958
# 2          60         74.0    13830            5            5       1997
# 3          60         78.0     9978            6            6       1998
# 4         120         43.0     5005            8            5       1992
# 5          60         75.0    10000            6            5       1993
# 6          20          NaN     7980            6            7       1992
# 7          60         63.0     8402            6            5       1998
# 8          20         85.0    10176            7            5       1990
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0          1961         0.0       468.0       144.0  ...       730.0
# 1          1958       108.0       923.0         0.0  ...       312.0
# ...

# %%
from matplotlib import pyplot as plt # improting the Matplotlib's plotting interface under the name of plt (calling by the functions)
data3['GarageArea'].plot(kind='hist', bins=20, title='Garage-Area') # selecting age column, making the histogram, split the age in 20 equal sized intervals
plt.gca().spines[['top', 'right',]].set_visible(False) # calling "Get Current Axes" for drewing the plot, making the results in clear visibility

# %%
from matplotlib import pyplot as plt
data3['GarageArea'].plot(kind='line', figsize=(20, 4), title='Garage-Area') # drawing the line plot, making figure 8 inches wide and 4 inches tall, titled as "Garage-Area"
plt.gca().spines[['top', 'right']].set_visible(False) # calling "Get Current Axes" for drewing the plot, structuring of the plot in 4 bordres, making the clear visibility.

# %%
data3.sort_index(axis=1,ascending=True) #pandas Method that sorts either the row index (axis 0) or Column index (axis 1) by its label, making the order reverse (alphabetical)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          896         0          0             2       468.0       144.0
# 1         1329         0          0             3       923.0         0.0
# 2          928       701          0             3       791.0         0.0
# 3          926       678          0             3       602.0         0.0
# 4         1280         0          0             2       263.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallCond  \
# ...

# %% [markdown]
# #**5th Method of importing data in google colab : Direct import**
#
#
# ---
#
#
#
# ### **Import file directely to Google Colab without Mounting**
#
# pulling raw data files (CSV, Excel, JSON, SQL, etc.) straight into a DataFrame via one of the built-in "**pd.read_***" functions (e.g. **pd.read_csv("data.csv")**).
#
# ----
# ### **1- Reads the file off disk (or steam)**
#
# ### **2- Parses the missing value:**
#
# *Scan every cell in the file and, by default, treat empty fields (and common placeholders like NA, n/a, blank strings, etc.) as NaN.*
#
# ### **3- Returns a fully populated DataFrame:**

# %%
from google.colab import files #provides utilities for uploading and downloading files between your local machine and the Colab VM.
import pandas as pd #importing the pandas library for working on DataFrames
import io #gives you in-memory “file-like” objects (e.g. buffers) that pandas can read from.

uploaded = files.upload()

filename = list(uploaded.keys())[0]  # Get the actual filename from uploaded
df5 = pd.read_csv(io.BytesIO(uploaded[filename])) #fetches the raw bytes of the file you just uploaded.
# Out:
#      <input type="file" id="files-0251b247-f78b-4d43-8597-2d32816e85b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0251b247-f78b-4d43-8597-2d32816e85b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##**buffer**
# is simply an area of memory used to temporarily hold data while it is being moved from one place to another.

# %%
df5
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             20         80.0    11622            5            6       1961
# 1             20         81.0    14267            6            6       1958
# 2             60         74.0    13830            5            5       1997
# 3             60         78.0     9978            6            6       1998
# 4            120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
df5.info() # this code gives us the genreal information about the dataframe including number of missing data and their types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 36 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   LotFrontage    1232 non-null   float64
#  2   LotArea        1459 non-null   int64
#  3   OverallQual    1459 non-null   int64
#  4   OverallCond    1459 non-null   int64
#  5   YearBuilt      1459 non-null   int64
#  6   YearRemodAdd   1459 non-null   int64
#  7   MasVnrArea     1444 non-null   float64
#  8   BsmtFinSF1     1458 non-null   float64
#  9   BsmtFinSF2     1458 non-null   float64
#  10  BsmtUnfSF      1458 non-null   float64
#  11  TotalBsmtSF    1458 non-null   float64
#  12  1stFlrSF       1459 non-null   int64
#  13  2ndFlrSF       1459 non-null   int64
#  14  LowQualFinSF   1459 non-null   int64
#  15  GrLivArea      1459 non-null   int64
#  16  BsmtFullBath   1457 non-null   float64
# ...

# %%
df5.describe()
# Out:
#         MSSubClass  LotFrontage       LotArea  OverallQual  OverallCond  \
# count  1459.000000  1232.000000   1459.000000  1459.000000  1459.000000
# mean     57.378341    68.580357   9819.161069     6.078821     5.553804
# std      42.746880    22.376841   4955.517327     1.436812     1.113740
# min      20.000000    21.000000   1470.000000     1.000000     1.000000
# 25%      20.000000    58.000000   7391.000000     5.000000     5.000000
# 50%      50.000000    67.000000   9399.000000     6.000000     5.000000
# 75%      70.000000    80.000000  11517.500000     7.000000     6.000000
# max     190.000000   200.000000  56600.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1459.000000   1459.000000  1444.000000  1458.000000  1458.000000  ...
# mean   1971.357779   1983.662783   100.709141   439.203704    52.619342  ...
# std      30.390071     21.130467   177.625900   455.268042   176.753926  ...
# ...

# %% [markdown]
# ### **Delete missing data in a DataFrame**
#
# We use dropna() function to delete the whole row of the obeservation which has a missing data . This method ia applicable when we do not have data sample problem and we have enough data.

# %%
import pandas as pd
example=pd.read_csv('/content/bank-loan.csv')

# %%
example
# Out:
#      age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0     41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1     27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2     40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3     41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4     24   2       2        0      28     17.3   1.787436  3.056564      1.0
# ..   ...  ..     ...      ...     ...      ...        ...       ...      ...
# 845   34   1      12       15      32      2.7   0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7   4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8   0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8   0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9   0.899130  4.389870      NaN
#
# [850 rows x 9 columns]

# %% [markdown]
# # To delete the missing data from your dataset, you can use the function dropna()

# %%
example.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       850 non-null    int64
#  1   ed        850 non-null    int64
#  2   employ    850 non-null    int64
#  3   address   850 non-null    int64
#  4   income    850 non-null    int64
#  5   debtinc   850 non-null    float64
#  6   creddebt  850 non-null    float64
#  7   othdebt   850 non-null    float64
#  8   default   700 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 59.9 KB

# %%
example.describe()
# Out:
#               age          ed      employ     address      income     debtinc  \
# count  850.000000  850.000000  850.000000  850.000000  850.000000  850.000000
# mean    35.029412    1.710588    8.565882    8.371765   46.675294   10.171647
# std      8.041432    0.927784    6.777884    6.895016   38.543054    6.719441
# min     20.000000    1.000000    0.000000    0.000000   13.000000    0.100000
# 25%     29.000000    1.000000    3.000000    3.000000   24.000000    5.100000
# 50%     34.000000    1.000000    7.000000    7.000000   35.000000    8.700000
# 75%     41.000000    2.000000   13.000000   12.000000   55.750000   13.800000
# max     56.000000    5.000000   33.000000   34.000000  446.000000   41.300000
#
#          creddebt     othdebt     default
# count  850.000000  850.000000  700.000000
# mean     1.576805    3.078789    0.261429
# std      2.125840    3.398803    0.439727
# min      0.011696    0.045584    0.000000
# 25%      0.382176    1.045942    0.000000
# ...

# %%
example.head()
# Out:
#    age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0   41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4   24   2       2        0      28     17.3   1.787436  3.056564      1.0

# %%
example.tail()
# Out:
#      age  ed  employ  address  income  debtinc  creddebt   othdebt  default
# 845   34   1      12       15      32      2.7  0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7  4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8  0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8  0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9  0.899130  4.389870      NaN

# %%
#Clean=example.dropna()
Clean=example.dropna()

# %%
Clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 700 entries, 0 to 699
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       700 non-null    int64
#  1   ed        700 non-null    int64
#  2   employ    700 non-null    int64
#  3   address   700 non-null    int64
#  4   income    700 non-null    int64
#  5   debtinc   700 non-null    float64
#  6   creddebt  700 non-null    float64
#  7   othdebt   700 non-null    float64
#  8   default   700 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 54.7 KB

# %%
CleanC= example.dropna(axis=1) # by this code we delete whole column which we have missing data

# %%
CleanC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       850 non-null    int64
#  1   ed        850 non-null    int64
#  2   employ    850 non-null    int64
#  3   address   850 non-null    int64
#  4   income    850 non-null    int64
#  5   debtinc   850 non-null    float64
#  6   creddebt  850 non-null    float64
#  7   othdebt   850 non-null    float64
# dtypes: float64(3), int64(5)
# memory usage: 53.3 KB

# %%
CleanC
# Out:
#      age  ed  employ  address  income  debtinc   creddebt   othdebt
# 0     41   3      17       12     176      9.3  11.359392  5.008608
# 1     27   1      10        6      31     17.3   1.362202  4.000798
# 2     40   1      15       14      55      5.5   0.856075  2.168925
# 3     41   1      15       14     120      2.9   2.658720  0.821280
# 4     24   2       2        0      28     17.3   1.787436  3.056564
# ..   ...  ..     ...      ...     ...      ...        ...       ...
# 845   34   1      12       15      32      2.7   0.239328  0.624672
# 846   32   2      12       11     116      5.7   4.026708  2.585292
# 847   48   1      13       11      38     10.8   0.722304  3.381696
# 848   35   2       1       11      24      7.8   0.417456  1.454544
# 849   37   1      20       13      41     12.9   0.899130  4.389870
#
# [850 rows x 8 columns]

# %%
import pandas
pandas.__version__
# Out:
# '2.2.2'

# %% [markdown]
# #**3-DataPanel**
#
# 3-dimentional data_structure which has 3 axes such as:
#
# - object
# - feature
# - index
#
#
# Nowadays are removed from Panda becasue of being less efficient for data processing, and its complicated structure.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# instead of using DataPanels, MultiIndex DataFrame is using for 3D or 4D tasks.

# %% [markdown]
# ##**!pip install pandas**
#
# is simply the notebook way of telling your Python environment, “Please make sure the pandas library is installed so I can use it in my code.”

# %%
! pip install Pandas

# %%
# prompt: show me all arguments of the function dropna

help(pd.DataFrame.dropna)
# Out:
# Help on function dropna in module pandas.core.frame:
#
# dropna(self, *, axis: 'Axis' = 0, how: 'AnyAll | lib.NoDefault' = <no_default>, thresh: 'int | lib.NoDefault' = <no_default>, subset: 'IndexLabel | None' = None, inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None'
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
# ...

# %% [markdown]
# ## Section 2: Data Visualization

# %% [markdown]
# #***Visualisation***

# %% [markdown]
# # We import two libraries ( numpy and matplotlib.pyplot)
#
# # Matplotlib is a basic visualization tool in Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
years = [1960, 1970, 1980, 1990, 2000, 2010, 2020]
pop = [21.91, 28.51, 38.67, 56.23, 66.13, 74.57, 80.28]

# %% [markdown]
# ### **Matplotlib**

# %% [markdown]
# ## **Line Plot**
#
# ---
#
#
#
# Lines show us the direction of change or tendency among two variables

# %% [markdown]
# # with this function we can drow a line with X and Y
# Always for plotting we should write **show** function
#
# In Jupyter, the `plt.show()` command forces the plot to appear below the cell, otherwise sometimes the plot might not display properly.

# %%
plt.plot(years, pop)
plt.show()

# %% [markdown]
# It's a custom labeling of the y-axis using `plt.yticks()`.

# %%
plt.figure(figsize=(10, 5), dpi=100) # this command is about the window of illustration
plt.plot(years, pop, color='skyblue',linewidth=4) # this command is for plotting
plt.xlabel('Year') # from this line till plt.show it is the setting of the plot (line)
plt.ylabel('Population')
plt.title('Country Population')
plt.yticks([21.91, 28.51, 38.67, 56.23, 66.13, 74.57, 80.28],['21M','28M','38M','56M','66M','74M','80M'])
plt.show()

# %% [markdown]
# ## **Scatter Plot**
#
#
# ---
#
#
# A good tool for correlation analysis and for identifying clusters or classes

# %% [markdown]
# scatter ( X,Y)

# %%
plt.scatter(years, pop)
plt.show()

# %%
popsize = np.array(pop)*5
popsize
# Out:
# array([109.55, 142.55, 193.35, 281.15, 330.65, 372.85, 401.4 ])

# %%
plt.scatter(years, pop, s=popsize , c='green')  # this is drowing for scatter points
plt.xlabel('Year') # from this line till plt.show is setting of the scatter diagram
plt.ylabel('Population')
plt.title('Country Population')
plt.yticks([21.91, 28.51, 38.67, 56.23, 66.13, 74.57, 80.28],['21M','28M','38M','56M','66M','74M','80M'])
plt.show()

# %%
plt.plot(years,pop,c='green',linewidth=5)
plt.scatter(years, pop, s=popsize , c='green')  # this is drowing for scatter points and based on the "popsize" size and green color.
plt.xlabel('Year') # from this line till plt.show is setting of the scatter diagram
plt.ylabel('Population')
plt.title('Country Population')
plt.yticks([21.91, 28.51, 38.67, 56.23, 66.13, 74.57, 80.28],['21M','28M','38M','56M','66M','74M','80M'])
plt.show()

# %%
popsize = np.array(pop)*4
popsize
# Out:
# array([ 87.64, 114.04, 154.68, 224.92, 264.52, 298.28, 321.12])

# %%
plt.scatter(years, pop, s=popsize , c='red')  # this is drowing for scatter points
plt.xlabel('Year') # from this line till plt.show is setting of the scatter diagram
plt.ylabel('Population')
plt.title('Country Population')
plt.yticks([21.91, 28.51, 38.67, 56.23, 66.13, 74.57, 80.28],['21M','28M','38M','56M','66M','74M','80M'])
plt.show()

# %%
plt.plot(years,pop,c='red',linewidth=6)
plt.scatter(years, pop, s=popsize , c='red')  # this is drowing for scatter points and based on the "popsize" size and green color.
plt.xlabel('Year') # from this line till plt.show is setting of the scatter diagram
plt.ylabel('Population')
plt.title('Country Population')
plt.yticks([21.91, 28.51, 38.67, 56.23, 66.13, 74.57, 80.28],['21M','28M','38M','56M','66M','74M','80M'])
plt.show()

# %% [markdown]
# ## **Bar Chart**
#
#
# ---
#
#
# The best tool for comparison and visualization of cathegorical paramaters

# %%
# Look at index 4 and 6, which demonstrate overlapping cases.
# red bar
t1 = [1, 3, 4, 5, 6, 7, 9]
tt1 = [4, 7, 8, 4, 7, 8, 3]

# green bar
t2 = [2, 4, 6, 8, 10]
tt2 = [5, 6, 2, 6, 2]

# Colors: https://matplotlib.org/api/colors_api.html

plt.bar(t1, tt1, label="Red Bar", color='red')

plt.bar(t2, tt2, label="Green Bar", color='green')


plt.xlabel('group')
plt.ylabel("bar height")
plt.title("Bar Chart Example")
plt.legend() # this code is for putting legend on top of the diagram.
plt.show()

# %% [markdown]
# ##*Horizontal Bar Chart*
#
# `plt.barh()`

# %%
import matplotlib.pyplot as plt
import numpy as np # creating fast and powerful functions for working with numerical data.

# create dataset
height = [5.8, 12.2, 21.5]
bars = ('Gruber& Narayanan(2019)', 'Konig & conway (2016)', 'Conway et.al (2017)')

# Create horizontal bars
plt.barh(bars, height)



# Add title
plt.ylabel('References')
plt.xlabel('Distance(km)')
plt.title('Average daily distance(km)')

# Show graphic
plt.show()

# %% [markdown]
# ### ***Histogram Plot***
#
# # Histogram Helps to Get Idea About Distribution
# always has one variable and another axis is  number of observation of each amount of variable.
#
# Histogram shows the type distribution of data , whether it is normal or abnormal , moreover it shows the amount of standard deviation sd.
#
# We usually use histogram for discrete numbers (like counts: 1,2,3,4,...) , but if we have continuous numbers then , it group the numbers into ranges out of the numbers.
#
# ###1- The blue distribution is the most centered and narrow.
# Very consistent values and tightly clustered around the mean.
#
# ###2- red distribution is shifted to the right, data is larger in value.
# Moderate variation and higher average value
#
#
# ###3- The green distribution is slightly to the left and more spread out.
# Higher Variation and lower value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We create a list of cities in Iran with differetn populations.
#
# This list is not directly used in the plot but define the context of population of IRAN.
#
#
# based on the output, Most major Iranian cities have similar populations (~1–3 million).
#
# Additionally, Tehran is an outlier with a much larger population which is very clearly shown by its isolated bar.

# %%
city_name = ['Tehran', 'Mashhad', 'Isfahan', 'Karaj', 'Tabriz', 'Shiraz']
city_pop = [7153309, 2307177, 1947164, 1448075, 1424641, 1249942]

# %%
import matplotlib.pyplot as plt #library for all types of plots and graphs including histograms.
plt.figure(figsize=(6,6), dpi=100)
plt.bar(city_name, city_pop)
plt.show()

plt.hist(city_pop,color='skyblue')
plt.xlabel('population')
plt.ylabel('City Number: Frequency') # describe how many cities fall into each bin=group
plt.grid(True, linestyle='--', alpha=0.5) # drawing the grid
plt.show()

# %%
import matplotlib.pyplot as plt

city_name = ['Tehran', 'Mashhad', 'Isfahan', 'Karaj', 'Tabriz', 'Shiraz']
city_pop = [7153309, 2307177, 1947164, 1448075, 1424641, 1249942]

plt.figure(figsize=(6,4), dpi=100)

# Draw the histogram
plt.hist(city_pop, bins=5, color='skyblue', edgecolor='black', alpha=0.7)

# Labels
plt.xlabel('Population')
plt.ylabel('Number of Cities (Frequency)')
plt.title('City Population Distribution')

plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### ***Pie Chart***
#
# # **The best chart to show percentage**

# %%
plt.pie(city_pop,labels = city_name)
plt.show()

# %%
# : how to select color gradian in pet.pie

colors = ['red', 'green', 'blue', 'yellow', 'orange', 'purple']
plt.pie(city_pop, labels=city_name, colors=colors)
plt.show()

# %%
plt.pie(city_pop,labels=city_name, autopct='%0.2f%%') # creation a pie chart based on the city_pop datasets, with using the name of the cities as labels and demonstrating the population of each city in decimal numbers with 1 decimal place.
plt.show()

# %% [markdown]
# ###**Customization** plots

# %% [markdown]
# ### **`Seaborn`**
#
# ## seaborn is based on the matplotlib and work with Pandas Data Structures. It has more advanced graphic tools than matplotlib.

# %% [markdown]
# Example: Blood Pressure

# %%
import pandas as pd #importing pandas library for data analytics
import seaborn as sb #importing seaborn for creation statistical graphics

# %%
example3=pd.read_csv('/content/blood_pressure.csv')
example3
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
example3.shape #showing the number of rows and columns respectively.
# Out:
# (120, 5)

# %%
example3.info() #giving the summary of the Data Structure. such as number of rows and columns, number of non missing values in each column,the memory usage of the DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   patient    120 non-null    int64
#  1   sex        120 non-null    object
#  2   agegrp     120 non-null    object
#  3   bp_before  120 non-null    int64
#  4   bp_after   120 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.8+ KB

# %%
# Giving the summary of numeric columns
example3.describe()
# Out:
#           patient   bp_before    bp_after
# count  120.000000  120.000000  120.000000
# mean    60.500000  156.450000  151.358333
# std     34.785054   11.389845   14.177622
# min      1.000000  138.000000  125.000000
# 25%     30.750000  147.000000  140.750000
# 50%     60.500000  154.500000  149.500000
# 75%     90.250000  164.000000  161.000000
# max    120.000000  185.000000  185.000000

# %% [markdown]
# # **Box Plot**
#
#
# ---
#
#
# **In Box Plot , we can show the median, 25 percentile (Q1) , 75 percentile (Q3) , upper extreme and lower extreme . By this plot , we can idetify the outliers of the data distribution including upper and lower outliers.** **IQR = Q3-Q1**
#
#
# ### ***The size of the box is important becasue it shows how data is distributed and which range has most distribuation of data***
# *italicized text*

# %%
import seaborn as sb
import matplotlib.pyplot as plt

sb.boxplot(y='bp_after', data=example3) #showing the box p;ot of the blood pressure after the treatment
plt.show()

# %%
# Giving the summary of numeric columns for Blood Pressure before treatment (selecting 1 column)
example3['bp_before'].describe()
# Out:
# count    120.000000
# mean     156.450000
# std       11.389845
# min      138.000000
# 25%      147.000000
# 50%      154.500000
# 75%      164.000000
# max      185.000000
# Name: bp_before, dtype: float64

# %% [markdown]
# | Metric           | Value   | Meaning                                                                |
# | ---------------- | ------- | ---------------------------------------------------------------------- |
# | **count**        | 120     | There are 120 blood pressure values recorded.                          |
# | **mean**         | 156.45  | The **average (mean)** blood pressure before treatment.                |
# | **std**          | 11.39   | The **standard deviation**, indicating moderate variation in values.   |
# | **min**          | 138.0   | The **lowest** recorded blood pressure value.                          |
# | **25% (Q1)**     | 147.0   | 25% of people had BP ≤ 147.0                                           |
# | **50% (median)** | 154.5   | 50% of people had BP ≤ 154.5 (this is the **median**).                 |
# | **75% (Q3)**     | 164.0   | 75% of people had BP ≤ 164.0                                           |
# | **max**          | 185.0   | The **highest** recorded blood pressure value.                         |
# | **dtype**        | float64 | The data is in **floating-point format**, suitable for decimal values. |

# %%
example3[['bp_before','bp_after']].describe()
# Out:
#         bp_before    bp_after
# count  120.000000  120.000000
# mean   156.450000  151.358333
# std     11.389845   14.177622
# min    138.000000  125.000000
# 25%    147.000000  140.750000
# 50%    154.500000  149.500000
# 75%    164.000000  161.000000
# max    185.000000  185.000000

# %%
# Melt the DataFrame to long format
melted_data = pd.melt(example3, id_vars=['patient', 'sex', 'agegrp'],
                      value_vars=['bp_before', 'bp_after'],
                      var_name='bp_type', value_name='bp_value')

# Create the box plot using the melted data
sb.boxplot(x='bp_type', y='bp_value', data=melted_data)
plt.show()

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Assuming 'example3' is the intended DataFrame
sb.boxplot(x='sex', y='bp_before', data=example3)  # selecting x as the gender of people, seaborn able to categorized them automatically.
plt.show()

# %%
sb.boxplot(x='agegrp',y='bp_before',data=example3)
# Out:
# <Axes: xlabel='agegrp', ylabel='bp_before'>

# %% [markdown]
# # ***Strip Plot***
#
#
# ---
#
#
# ## plots the distribution of variables for each category as individual datapoints

# %%
import pandas as pd #importing pandas library for data analytics
import seaborn as sb #importing seaborn for creation statistical graphics

# %%
smartphones=pd.read_csv('/content/smartphones.csv')
smartphones
# Out:
#         Name        OS  Capacity  Ram  Weight    Company  inch
# 0  Galaxy S8   Android        64    4   149.0    Samsung   5.8
# 1  Lumia 950  windows         32    3   150.0  Microsoft   5.2
# 2  Xpreia L1   Android        16    2   180.0       Sony   5.5
# 3  iphone 7        ios       128    2   138.0      Apple   4.7
# 4    U Ultra   Android        64    4   170.0        HTC   5.7
# 5  Galaxy S5   Android        16    2   145.0    Samsung   5.1
# 6  iphone 5s       ios        32    1   112.0      Apple   4.0
# 7    Moto G5   Android        16    3   144.5   Motorola   5.0
# 8     Pixel    Android       128    4   143.0     Google   5.0

# %%
smartphones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      9 non-null      object
#  1   OS        9 non-null      object
#  2   Capacity  9 non-null      int64
#  3   Ram       9 non-null      int64
#  4   Weight    9 non-null      float64
#  5   Company   9 non-null      object
#  6   inch      9 non-null      float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 636.0+ bytes

# %%
smartphones.describe()
# Out:
#          Capacity       Ram      Weight      inch
# count    9.000000  9.000000    9.000000  9.000000
# mean    55.111111  2.777778  147.944444  5.111111
# std     45.333333  1.092906   19.219854  0.548736
# min     16.000000  1.000000  112.000000  4.000000
# 25%     16.000000  2.000000  143.000000  5.000000
# 50%     32.000000  3.000000  145.000000  5.100000
# 75%     64.000000  4.000000  150.000000  5.500000
# max    128.000000  4.000000  180.000000  5.800000

# %%
plt.figure(figsize=(13,8))
sb.stripplot(x='OS', y='Capacity', data=smartphones, hue='Ram', size=30)
plt.show()

# %% [markdown]
# ### ***Swarm Plot***
#
# ## This function is similar to stripplot(), but the points are adjusted (only along the categorical axis)
# ## **so that they don’t overlap on each other**

# %%
plt.figure(figsize=(13,8))
sb.swarmplot(x='OS', y='Capacity', data=smartphones, hue='Ram', size=30)
plt.show()

# %%
plt.figure(figsize=(13,8))
sb.swarmplot(x='OS', y='Capacity', data=smartphones, hue='Company', size=30) # a swarm plot showing different companies with their capacity and their software which don't overlap each other
plt.show()

# %% [markdown]
# ## The argumnet : (X,Y, dataframe)

# %% [markdown]
# # ***Pair Plot***
#
#
# ---
#
#
# ###This plot is good practical plot to undestand the corellations between variable pairs
#
# Plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each numeric variable in ``data`` will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
#
#
# It is also possible to show a subset of variables or plot different variables on the rows and columns.

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt


salaries = pd.read_csv('/content/Salaries.csv')
salaries
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
sb.set_style('darkgrid') # this the command for changing backgroun of the graph

sb.pairplot(salaries, hue='rank',plot_kws={'s':100}) # creating the pair plot based on the dataframe of salaries, data is explained basd on the rank type "professors"
plt.show()

# %%
plt.scatter(salaries['phd'],salaries['salary'])
plt.show()

# %%
plt.hist(salaries['rank'])
plt.show()
